# %%
import numpy as np
import time

import PIL.Image as Image
import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub

import os
import shutil
from sklearn.model_selection import train_test_split
from tqdm import tqdm

import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
pip install --upgrade tensorflow tensorflow-hub
# Out:
# ...
#   WARNING: Failed to remove contents in a temporary directory 'D:\EDI_FINAL\.venv\Lib\site-packages\~ensorflow'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/300.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/300.9 MB 1.7 MB/s eta 0:02:53
#    ---------------------------------------- 0.5/300.9 MB 6.2 MB/s eta 0:00:49
#    ---------------------------------------- 1.3/300.9 MB 11.6 MB/s eta 0:00:26
#    ---------------------------------------- 3.0/300.9 MB 19.1 MB/s eta 0:00:16
#     --------------------------------------- 4.9/300.9 MB 26.2 MB/s eta 0:00:12
#     --------------------------------------- 6.8/300.9 MB 29.1 MB/s eta 0:00:11
#    - -------------------------------------- 8.8/300.9 MB 33.3 MB/s eta 0:00:09
# ...

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import tensorflow as tf
import numpy as np

# Load the trained model
model_path = "D:/EDI_FINAL/models/sugercane_model.h5"
loaded_model = tf.keras.models.load_model(model_path)

# Preprocess the input image
def preprocess_image(image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create batch axis
    img_array /= 255.0  # Normalize the image
    return img_array

# Class names
class_names = ['Bacterial Blight', 'Healthy' ,'Red Rot']  # Replace with your actual class names

# Function to perform classification
def classify_image():
    file_path = filedialog.askopenfilename(initialdir="/", title="Select Image",
                                           filetypes=(("Image files", "*.png;*.jpg;*.jpeg"), ("all files", "*.*")))
    if file_path:
        input_image = preprocess_image(file_path)
        predictions = loaded_model.predict(input_image)
        predicted_class = class_names[np.argmax(predictions)]
        result_label.config(text=f"Predicted Class: {predicted_class}", font=("Times New Roman", 12, "bold"))

        # Display the input image
        img = Image.open(file_path)
        img.thumbnail((400, 300))  # Resize image to fit window dimensions
        img_tk = ImageTk.PhotoImage(img)
        input_image_label.config(image=img_tk)
        input_image_label.image = img_tk

# Create the main Tkinter window
root = tk.Tk()
root.title("Plant Disease Classification")
root.geometry("600x400")

# Create widgets
browse_button = tk.Button(root, text="Browse Image", command=classify_image)
result_label = tk.Label(root, text="Predicted Class: ", font=("Times New Roman", 11, "bold"))
input_image_label = tk.Label(root)

# Arrange widgets in the layout
browse_button.pack(pady=10)
result_label.pack()
input_image_label.pack(pady=10)

# Run the Tkinter main loop
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 15
#      12     custom_objects = {"KerasLayer": hub.KerasLayer}
#      13     return tf.keras.models.load_model(model_path, custom_objects=custom_objects)
# ---> 15 model_path = tf.keras.saving.load_model('D:/EDI_FINAL/models/sugercane_model.h5', custom_objects={'KerasLayer': hub.KerasLayer})
#      16 loaded_model = load_model_with_hub(model_path)
#      18 # Preprocess the input image
#
# File d:\EDI_FINAL\.venv\lib\site-packages\keras\src\saving\saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
# ...

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import tensorflow as tf
import numpy as np
import tensorflow_hub as hub

# Register the KerasLayer before loading the model
def load_model_with_hub(model_path):
    # Define a custom object scope to include the KerasLayer
    custom_objects = {"KerasLayer": hub.KerasLayer}
    return tf.keras.models.load_model(model_path, custom_objects=custom_objects)

# Load the trained model
model_path = "D:/EDI_FINAL/models/sugercane_model.h5"
loaded_model = load_model_with_hub(model_path)

# Preprocess the input image
def preprocess_image(image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create batch axis
    img_array /= 255.0  # Normalize the image
    return img_array

# Class names
class_names = ['Bacterial Blight', 'Healthy', 'Red Rot']  # Replace with your actual class names

# Function to perform classification
def classify_image():
    file_path = filedialog.askopenfilename(initialdir="/", title="Select Image",
                                           filetypes=(("Image files", "*.png;*.jpg;*.jpeg"), ("all files", "*.*")))
    if file_path:
        input_image = preprocess_image(file_path)
        predictions = loaded_model.predict(input_image)
        predicted_class = class_names[np.argmax(predictions)]
        result_label.config(text=f"Predicted Class: {predicted_class}", font=("Times New Roman", 12, "bold"))

        # Display the input image
        img = Image.open(file_path)
        img.thumbnail((400, 300))  # Resize image to fit window dimensions
        img_tk = ImageTk.PhotoImage(img)
        input_image_label.config(image=img_tk)
        input_image_label.image = img_tk

        # Display the classified image below
        classified_img = Image.fromarray((input_image[0] * 255).astype(np.uint8))
        classified_img_tk = ImageTk.PhotoImage(classified_img)
        classified_image_label.config(image=classified_img_tk)
        classified_image_label.image = classified_img_tk

# Create the main Tkinter window
root = tk.Tk()
root.title("Plant Disease Classification")

root.geometry("600x400")

# Create widgets
browse_button = tk.Button(root, text="Browse Image", command=classify_image)
result_label = tk.Label(root, text="Predicted Class: ", font=("Times New Roman", 11, "bold"))
input_image_label = tk.Label(root)
classified_image_label = tk.Label(root)

# Arrange widgets in the layout
browse_button.pack(pady=10)
result_label.pack()
input_image_label.pack(pady=10)
classified_image_label.pack()

# Run the Tkinter main loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import tensorflow as tf
import numpy as np
import tensorflow_hub as hub

# Register the KerasLayer before loading the model
def load_model_with_hub(model_path):
    # Define a custom object scope to include the KerasLayer
    custom_objects = {"KerasLayer": hub.KerasLayer}
    return tf.keras.models.load_model(model_path, custom_objects=custom_objects)

# Load the trained model
model_path = "D:/EDI_FINAL/models/maize_model.h5"
loaded_model = load_model_with_hub(model_path)

# Preprocess the input image
def preprocess_image(image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create batch axis
    img_array /= 255.0  # Normalize the image
    return img_array

# Class names
class_names = ['Blight', 'Common_Rust', 'Gray_Leaf_Spot,Healthy'],  # Replace with your actual class names


# Function to perform classification
def classify_image():
    file_path = filedialog.askopenfilename(initialdir="/", title="Select Image",
                                           filetypes=(("Image files", "*.png;*.jpg;*.jpeg"), ("all files", "*.*")))
    if file_path:
        input_image = preprocess_image(file_path)
        predictions = loaded_model.predict(input_image)
        predicted_class = class_names[np.argmax(predictions)]
        result_label.config(text=f"Predicted Class: {predicted_class}", font=("Times New Roman", 12, "bold"))

        # Display the input image
        img = Image.open(file_path)
        img.thumbnail((400, 300))  # Resize image to fit window dimensions
        img_tk = ImageTk.PhotoImage(img)
        input_image_label.config(image=img_tk)
        input_image_label.image = img_tk

        # Display the classified image below
        classified_img = Image.fromarray((input_image[0] * 255).astype(np.uint8))
        classified_img_tk = ImageTk.PhotoImage(classified_img)
        classified_image_label.config(image=classified_img_tk)
        classified_image_label.image = classified_img_tk

# Create the main Tkinter window
root = tk.Tk()
root.title("Plant Disease Classification")

root.geometry("600x400")

# Create widgets
browse_button = tk.Button(root, text="Browse Image", command=classify_image)
result_label = tk.Label(root, text="Predicted Class: ", font=("Times New Roman", 11, "bold"))
input_image_label = tk.Label(root)
classified_image_label = tk.Label(root)

# Arrange widgets in the layout
browse_button.pack(pady=10)
result_label.pack()
input_image_label.pack(pady=10)
classified_image_label.pack()

# Run the Tkinter main loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import tensorflow as tf
import numpy as np
import tensorflow_hub as hub

# Register the KerasLayer before loading the model
def load_model_with_hub(model_path):
    # Define a custom object scope to include the KerasLayer
    custom_objects = {"KerasLayer": hub.KerasLayer}
    return tf.keras.models.load_model(model_path, custom_objects=custom_objects)

# Load the trained model
model_path = "D:/EDI_FINAL/models/cotton_model.h5"
loaded_model = load_model_with_hub(model_path)

# Preprocess the input image
def preprocess_image(image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create batch axis
    img_array /= 255.0  # Normalize the image
    return img_array

# Class names
class_names = ['Bacterial blight','curl_virus', 'fussarium_wilt', 'Healthy'],  # Replace with your actual class names


# Function to perform classification
def classify_image():
    file_path = filedialog.askopenfilename(initialdir="/", title="Select Image",
                                           filetypes=(("Image files", "*.png;*.jpg;*.jpeg"), ("all files", "*.*")))
    if file_path:
        input_image = preprocess_image(file_path)
        predictions = loaded_model.predict(input_image)
        predicted_class = class_names[np.argmax(predictions)]
        result_label.config(text=f"Predicted Class: {predicted_class}", font=("Times New Roman", 12, "bold"))

        # Display the input image
        img = Image.open(file_path)
        img.thumbnail((400, 300))  # Resize image to fit window dimensions
        img_tk = ImageTk.PhotoImage(img)
        input_image_label.config(image=img_tk)
        input_image_label.image = img_tk

        # Display the classified image below
        classified_img = Image.fromarray((input_image[0] * 255).astype(np.uint8))
        classified_img_tk = ImageTk.PhotoImage(classified_img)
        classified_image_label.config(image=classified_img_tk)
        classified_image_label.image = classified_img_tk

# Create the main Tkinter window
root = tk.Tk()
root.title("Plant Disease Classification")

root.geometry("600x400")

# Create widgets
browse_button = tk.Button(root, text="Browse Image", command=classify_image)
result_label = tk.Label(root, text="Predicted Class: ", font=("Times New Roman", 11, "bold"))
input_image_label = tk.Label(root)
classified_image_label = tk.Label(root)

# Arrange widgets in the layout
browse_button.pack(pady=10)
result_label.pack()
input_image_label.pack(pady=10)
classified_image_label.pack()

# Run the Tkinter main loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import tensorflow as tf
import numpy as np
import tensorflow_hub as hub

# Register the KerasLayer before loading the model
def load_model_with_hub(model_path):
    # Define a custom object scope to include the KerasLayer
    custom_objects = {"KerasLayer": hub.KerasLayer}
    return tf.keras.models.load_model(model_path, custom_objects=custom_objects)

# Load the trained model
model_path = "D:/EDI_FINAL/models/rice_model.h5"
loaded_model = load_model_with_hub(model_path)

# Preprocess the input image
def preprocess_image(image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create batch axis
    img_array /= 255.0  # Normalize the image
    return img_array

# Class names
class_names = ['Bacterial_blight', 'Blast', 'Brownspot', 'Tungro'],  # Replace with your actual class names


# Function to perform classification
def classify_image():
    file_path = filedialog.askopenfilename(initialdir="/", title="Select Image",
                                           filetypes=(("Image files", "*.png;*.jpg;*.jpeg"), ("all files", "*.*")))
    if file_path:
        input_image = preprocess_image(file_path)
        predictions = loaded_model.predict(input_image)
        predicted_class = class_names[np.argmax(predictions)]
        result_label.config(text=f"Predicted Class: {predicted_class}", font=("Times New Roman", 12, "bold"))

        # Display the input image
        img = Image.open(file_path)
        img.thumbnail((400, 300))  # Resize image to fit window dimensions
        img_tk = ImageTk.PhotoImage(img)
        input_image_label.config(image=img_tk)
        input_image_label.image = img_tk

        # Display the classified image below
        classified_img = Image.fromarray((input_image[0] * 255).astype(np.uint8))
        classified_img_tk = ImageTk.PhotoImage(classified_img)
        classified_image_label.config(image=classified_img_tk)
        classified_image_label.image = classified_img_tk

# Create the main Tkinter window
root = tk.Tk()
root.title("Plant Disease Classification")

root.geometry("600x400")

# Create widgets
browse_button = tk.Button(root, text="Browse Image", command=classify_image)
result_label = tk.Label(root, text="Predicted Class: ", font=("Times New Roman", 11, "bold"))
input_image_label = tk.Label(root)
classified_image_label = tk.Label(root)

# Arrange widgets in the layout
browse_button.pack(pady=10)
result_label.pack()
input_image_label.pack(pady=10)
classified_image_label.pack()

# Run the Tkinter main loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import tensorflow as tf
import numpy as np
import tensorflow_hub as hub

# Register the KerasLayer before loading the model
def load_model_with_hub(model_path):
    # Define a custom object scope to include the KerasLayer
    custom_objects = {"KerasLayer": hub.KerasLayer}
    return tf.keras.models.load_model(model_path, custom_objects=custom_objects)

# Load the trained model
model_path = "D:/EDI_FINAL/models/wheat_model.h5"
loaded_model = load_model_with_hub(model_path)

# Preprocess the input image
def preprocess_image(image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create batch axis
    img_array /= 255.0  # Normalize the image
    return img_array

# Class names
class_names = ['Healthy', 'septoria', 'strip_rust'],  # Replace with your actual class names


# Function to perform classification
def classify_image():
    file_path = filedialog.askopenfilename(initialdir="/", title="Select Image",
                                           filetypes=(("Image files", "*.png;*.jpg;*.jpeg"), ("all files", "*.*")))
    if file_path:
        input_image = preprocess_image(file_path)
        predictions = loaded_model.predict(input_image)
        predicted_class = class_names[np.argmax(predictions)]
        result_label.config(text=f"Predicted Class: {predicted_class}", font=("Times New Roman", 12, "bold"))

        # Display the input image
        img = Image.open(file_path)
        img.thumbnail((400, 300))  # Resize image to fit window dimensions
        img_tk = ImageTk.PhotoImage(img)
        input_image_label.config(image=img_tk)
        input_image_label.image = img_tk

        # Display the classified image below
        classified_img = Image.fromarray((input_image[0] * 255).astype(np.uint8))
        classified_img_tk = ImageTk.PhotoImage(classified_img)
        classified_image_label.config(image=classified_img_tk)
        classified_image_label.image = classified_img_tk

# Create the main Tkinter window
root = tk.Tk()
root.title("Plant Disease Classification")

root.geometry("600x400")

# Create widgets
browse_button = tk.Button(root, text="Browse Image", command=classify_image)
result_label = tk.Label(root, text="Predicted Class: ", font=("Times New Roman", 11, "bold"))
input_image_label = tk.Label(root)
classified_image_label = tk.Label(root)

# Arrange widgets in the layout
browse_button.pack(pady=10)
result_label.pack()
input_image_label.pack(pady=10)
classified_image_label.pack()

# Run the Tkinter main loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import tensorflow as tf
import numpy as np
import tensorflow_hub as hub

# Function to load a model with TensorFlow Hub layer
def load_model_with_hub(model_path):
    # Define a custom object scope to include the KerasLayer
    custom_objects = {"KerasLayer": hub.KerasLayer}
    return tf.keras.models.load_model(model_path, custom_objects=custom_objects)

# Load all four models
models = {
    'sugarcane': load_model_with_hub("models/sugercane_model.h5"),
    'maize': load_model_with_hub("models/maize_model.h5"),
    'cotton': load_model_with_hub("models/cotton_model.h5"),
    'rice': load_model_with_hub("models/rice_model.h5"),
    'wheat': load_model_with_hub("models/wheat_model.h5"),
}

# Class names for each modela
class_names = {
    'sugarcane': ['Bacterial Blight', 'Healthy', 'Red Rot'],
    'maize': ['Blight', 'Common_Rust', 'Gray_Leaf_Spot,Healthy'],  # Replace with your actual class names
    'cotton': ['Bacterial blight','curl_virus', 'fussarium_wilt', 'Healthy'],  # Replace with your actual class names
    'rice': ['Bacterial_blight', 'Blast', 'Brownspot', 'Tungro'],  # Replace with your actual class names
    'wheat': ['Healthy', 'septoria', 'strip_rust'],  # Replace with your actual class names
}

# Function to preprocess an input image
def preprocess_image(image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create batch axis
    img_array /= 255.0  # Normalize the image
    return img_array

# Function to classify an image using the selected model
def classify_image(model_name, file_path):
    input_image = preprocess_image(file_path)
    predictions = models[model_name].predict(input_image)
    predicted_class = class_names[model_name][np.argmax(predictions)]
    result_label.config(text=f"Predicted Class ({model_name}): {predicted_class}", font=("Times New Roman", 12, "bold"))

    # Display the input image below the buttons
    img = Image.open(file_path)
    img.thumbnail((400, 300)) 
    img_tk = ImageTk.PhotoImage(img)
    input_image_label.config(image=img_tk)
    input_image_label.image = img_tk

# Function to handle the "Browse Image" button
def browse_image():
    file_path = filedialog.askopenfilename(initialdir="/", title="Select Image",
                                           filetypes=(("Image files", "*.png;*.jpg;*.jpeg"), ("all files", "*.*")))
    if file_path:
        browse_label.config(text=f"Selected Image: {file_path}")
        # Enable plant type buttons
        sugarcane_button.config(state=tk.NORMAL)
        maize_button.config(state=tk.NORMAL)
        cotton_button.config(state=tk.NORMAL)
        rice_button.config(state=tk.NORMAL)
        wheat_button.config(state=tk.NORMAL)
        # Save file path for later use
        browse_image.file_path = file_path

# Create the main Tkinter window
root = tk.Tk()
root.title("Plant Disease Classification")

root.geometry("700x700")

# Create widgets
browse_button = tk.Button(root, text="Browse Image", command=browse_image)
browse_label = tk.Label(root, text="Selected Image: ")

button_frame = tk.Frame(root)

sugarcane_button = tk.Button(button_frame, text="Sugarcane", command=lambda: classify_image('sugarcane', browse_image.file_path), state=tk.DISABLED)
maize_button = tk.Button(button_frame, text="Maize", command=lambda: classify_image('maize', browse_image.file_path), state=tk.DISABLED)
cotton_button = tk.Button(button_frame, text="Cotton", command=lambda: classify_image('cotton', browse_image.file_path), state=tk.DISABLED)
rice_button = tk.Button(button_frame, text="Rice", command=lambda: classify_image('rice', browse_image.file_path), state=tk.DISABLED)
wheat_button = tk.Button(button_frame, text="Wheat", command=lambda: classify_image('wheat', browse_image.file_path), state=tk.DISABLED)

result_label = tk.Label(root, text="Predicted Class: ", font=("Times New Roman", 11, "bold"))
input_image_label = tk.Label(root)

# Arrange widgets in the layout
browse_button.pack(pady=10)
browse_label.pack(pady=5)

button_frame.pack(pady=10)
sugarcane_button.pack(side="left", padx=5)
maize_button.pack(side="left", padx=5)
cotton_button.pack(side="left", padx=5)
rice_button.pack(side="left", padx=5)
wheat_button.pack(side="left", padx=5)

result_label.pack()
input_image_label.pack(pady=10)

# Run the Tkinter main loop
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 16
#      12     return tf.keras.models.load_model(model_path, custom_objects=custom_objects)
#      14 # Load all four models
#      15 models = {
# ---> 16     'sugarcane': load_model_with_hub("models/sugercane_model.h5"),
#      17     'maize': load_model_with_hub("models/maize_model.h5"),
#      18     'cotton': load_model_with_hub("models/cotton_model.h5"),
#      19     'rice': load_model_with_hub("models/rice_model.h5"),
#      20     'wheat': load_model_with_hub("models/wheat_model.h5"),
#      21 }
#      23 # Class names for each modela
#      24 class_names = {
#      25     'sugarcane': ['Bacterial Blight', 'Healthy', 'Red Rot'],
#      26     'maize': ['Blight', 'Common_Rust', 'Gray_Leaf_Spot,Healthy'],  # Replace with your actual class names
#    (...)
# ...

# %% [markdown]
# SUGERCANE

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import tensorflow as tf
import numpy as np
import tensorflow_hub as hub

# Register the KerasLayer before loading the model
def load_model_with_hub(model_path):
    # Define a custom object scope to include the KerasLayer
    custom_objects = {"KerasLayer": hub.KerasLayer}
    return tf.keras.models.load_model(model_path, custom_objects=custom_objects)

# Load the trained model
model_path = "D:/EDI_FINAL/models/sugercane_model.h5"
loaded_model = load_model_with_hub(model_path)

# Preprocess the input image
def preprocess_image(image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create batch axis
    img_array /= 255.0  # Normalize the image
    return img_array

# Class names
class_names = ['Bacterial Blight', 'Healthy', 'Red Rot']  # Replace with your actual class names

# Function to recommend pesticides based on the predicted class
def recommend_pesticides(predicted_class_index):
    pesticides = []

    if predicted_class_index == 0:  # Bacterial Blight
        pesticides = ['Streptomycin']
    elif predicted_class_index == 2:  # Red Rot
        pesticides = ['Mancozeb', 'Trichoderma viride']

    return pesticides

# Function to perform classification
def classify_image():
    file_path = filedialog.askopenfilename(initialdir="/", title="Select Image",
                                           filetypes=(("Image files", "*.png;*.jpg;*.jpeg"), ("all files", "*.*")))
    if file_path:
        input_image = preprocess_image(file_path)
        predictions = loaded_model.predict(input_image)
        predicted_class_index = np.argmax(predictions)
        predicted_class = class_names[predicted_class_index]
        result_label.config(text=f"Predicted Class: {predicted_class}", font=("Times New Roman", 12, "bold"))

        # Display the input image
        img = Image.open(file_path)
        img.thumbnail((400, 300))  # Resize image to fit window dimensions
        img_tk = ImageTk.PhotoImage(img)
        input_image_label.config(image=img_tk)
        input_image_label.image = img_tk

        # Get and display recommended pesticides
        pesticides = recommend_pesticides(predicted_class_index)
        pesticides_text = f"Recommended Pesticides: {', '.join(pesticides)}"
        pesticides_label.config(text=pesticides_text, font=("Times New Roman", 11, "bold"))

        # Print to console for verification
        print(pesticides_text)

# Create the main Tkinter window
root = tk.Tk()
root.title("Plant Disease Classification")

# Get the screen width and height
screen_width = root.winfo_screenwidth()
screen_height = root.winfo_screenheight()

# Set the window size and position
window_width = 700
window_height = 700
window_x = (screen_width - window_width) // 2
window_y = (screen_height - window_height) // 2

root.geometry(f"{window_width}x{window_height}+{window_x}+{window_y}")

# Create widgets
browse_button = tk.Button(root, text="Browse Image", command=classify_image, bg="black", fg="white", font=("Times New Roman", 16))
result_label = tk.Label(root, text="Predicted Class: ", font=("Times New Roman", 11, "bold"))
input_image_label = tk.Label(root)
pesticides_label = tk.Label(root)

# Pack widgets in the layout
browse_button.pack(pady=10)
result_label.pack()
input_image_label.pack(pady=10)
pesticides_label.pack(pady=10)

# Run the Tkinter main loop
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 16
#      14 # Load the trained model
#      15 model_path = "rice.h5"
# ---> 16 loaded_model = load_model_with_hub(model_path)
#      18 # Preprocess the input image
#      19 def preprocess_image(image_path):
#
# Cell In[2], line 12, in load_model_with_hub(model_path)
#       9 def load_model_with_hub(model_path):
#      10     # Define a custom object scope to include the KerasLayer
#      11     custom_objects = {"KerasLayer": hub.KerasLayer}
# ---> 12     return tf.keras.models.load_model(model_path, custom_objects=custom_objects)
#
# File d:\EDI_FINAL\.venv\lib\site-packages\keras\src\saving\saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
# ...

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import tensorflow as tf
import numpy as np
import tensorflow_hub as hub

# Register the KerasLayer before loading the model
def load_model_with_hub(model_path):
    # Define a custom object scope to include the KerasLayer
    custom_objects = {"KerasLayer": hub.KerasLayer}
    return tf.keras.models.load_model(model_path, custom_objects=custom_objects)

# Load the trained model
model_path = "models/rice_model.h5"
loaded_model = load_model_with_hub(model_path)

# Preprocess the input image
def preprocess_image(image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create batch axis
    img_array /= 255.0  # Normalize the image
    return img_array

# Class names for rice diseases
class_names_rice = ['Bacterial_blight', 'Blast', 'Brownspot', 'Tungro']

# Function to recommend pesticides based on the predicted class for rice diseases
def recommend_pesticides_rice(predicted_class_index):
    pesticides = []

    if predicted_class_index == 0:  # Bacterial Blight
        pesticides = ['streptomycin']
    elif predicted_class_index == 1:  # Blast
        pesticides = ['azoxystrobin, tricyclazole, or propiconazole']
    elif predicted_class_index == 2:  # Brownspot
        pesticides = [' propiconazole, hexaconazole, or tricyclazole']
    elif predicted_class_index == 3:  # Tungro
        pesticides = [' imidacloprid, thiamethoxam, or chlorpyrifos']

    return pesticides

# Function to perform classification for rice diseases
def classify_image_rice():
    file_path = filedialog.askopenfilename(initialdir="/", title="Select Image",
                                           filetypes=(("Image files", "*.png;*.jpg;*.jpeg"), ("all files", "*.*")))
    if file_path:
        input_image = preprocess_image(file_path)
        predictions = loaded_model.predict(input_image)
        predicted_class_index = np.argmax(predictions)
        predicted_class = class_names_rice[predicted_class_index]
        result_label_rice.config(text=f"Predicted Class: {predicted_class}", font=("Times New Roman", 12, "bold"))

        # Display the input image
        img = Image.open(file_path)
        img.thumbnail((400, 300))  # Resize image to fit window dimensions
        img_tk = ImageTk.PhotoImage(img)
        input_image_label_rice.config(image=img_tk)
        input_image_label_rice.image = img_tk

        # Get and display recommended pesticides for rice diseases
        pesticides_rice = recommend_pesticides_rice(predicted_class_index)
        pesticides_text_rice = f"Recommended Pesticides: {', '.join(pesticides_rice)}"
        pesticides_label_rice.config(text=pesticides_text_rice, font=("Times New Roman", 11, "bold"))

        # Print to console for verification
        print(pesticides_text_rice)

# Create the main Tkinter window for rice diseases
root_rice = tk.Tk()
root_rice.title("Rice Disease Classification")

# Get the screen width and height
screen_width_rice = root_rice.winfo_screenwidth()
screen_height_rice = root_rice.winfo_screenheight()

# Set the window size and position
window_width_rice = 700
window_height_rice = 700
window_x_rice = (screen_width_rice - window_width_rice) // 2
window_y_rice = (screen_height_rice - window_height_rice) // 2

root_rice.geometry(f"{window_width_rice}x{window_height_rice}+{window_x_rice}+{window_y_rice}")

# Create widgets for rice diseases
browse_button_rice = tk.Button(root_rice, text="Browse Image", command=classify_image_rice)
result_label_rice = tk.Label(root_rice, text="Predicted Class: ", font=("Times New Roman", 11, "bold"))
input_image_label_rice = tk.Label(root_rice)
pesticides_label_rice = tk.Label(root_rice)

# Pack widgets in the layout for rice diseases
browse_button_rice.pack(pady=10)
result_label_rice.pack()
input_image_label_rice.pack(pady=10)
pesticides_label_rice.pack(pady=10)

# Run the Tkinter main loop for rice diseases
root_rice.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 16
#      14 # Load the trained model
#      15 model_path = "models/rice_model.h5"
# ---> 16 loaded_model = load_model_with_hub(model_path)
#      18 # Preprocess the input image
#      19 def preprocess_image(image_path):
#
# Cell In[3], line 12, in load_model_with_hub(model_path)
#       9 def load_model_with_hub(model_path):
#      10     # Define a custom object scope to include the KerasLayer
#      11     custom_objects = {"KerasLayer": hub.KerasLayer}
# ---> 12     return tf.keras.models.load_model(model_path, custom_objects=custom_objects)
#
# File d:\EDI_FINAL\.venv\lib\site-packages\keras\src\saving\saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
# ...
